# %%
import pandas as pd
import random

# %%
df= pd.read_json('seven_data_shaped.json')
df
# Out:
#                      商品名           値段  \
# 0                ももももサンド  340（367.20）
# 1                ももももサンド  340（367.20）
# 2     シャインマスカット入りフルーツサンド  390（421.20）
# 3         大きなソーセージ　チリドッグ  310（334.80）
# 4            てりたまチーズバーガー  380（410.40）
# ...                  ...          ...
# 1493   ７プレミアムゼスプリグリーンキウイ  188（203.04）
# 1494         ちょこっとカットパイン  195（210.60）
# 1495          ７プレミアム干しいも  338（365.04）
# 1496  ７プレミアム　けんちん汁・豚汁用水煮  278（300.24）
# 1497       ７プレミアム　さといも水煮  248（267.84）
#
#                                                      説明  \
# 0          カスタードクリームとホイップクリームを組み合わせ、２種類の桃を使用したサンドイッチです。
# 1          カスタードクリームとホイップクリームを組み合わせ、２種類の桃を使用したサンドイッチです。
# 2     ９月～１０月に旬を迎えるマスカットを使用したフルーツサンド。他にもパイン、黄桃、みかんの３種...
# 3              パリッとジューシーなソーセージにスパイシーなチリソースとチーズを盛り付けました。
# 4     ビーフハンバーグと潰し目玉焼きとチェダーチーズを組み合わせ、照焼ソースとオーロラソースの２種...
# ...                                                 ...
# 1493
# 1494
# 1495                            ほど良い食感と素朴な甘さが特長の干しいもです。
# 1496                             下ごしらえいらず　家庭の味をちょっとお手伝い
# 1497                          開封したらすぐに使えて時間短縮、便利なさといも水煮
#
#                                         本製品に含まれるアレルギー物質  \
# 0     \n\t\t\t\t\t\t\t\t\t\t\t特定原材料7品目\n\t\t\t\t\t\t...
# 1     \n\t\t\t\t\t\t\t\t\t\t\t特定原材料7品目\n\t\t\t\t\t\t...
# 2     \n\t\t\t\t\t\t\t\t\t\t\t特定原材料7品目\n\t\t\t\t\t\t...
# 3     \n\t\t\t\t\t\t\t\t\t\t\t特定原材料7品目\n\t\t\t\t\t\t...
# 4     \n\t\t\t\t\t\t\t\t\t\t\t特定原材料7品目\n\t\t\t\t\t\t...
# ...                                                 ...
# 1493  \n\t\t\t\t\t\t\t\t\t\t\t特定原材料7品目\n\t\t\t\t\t\t...
# 1494                                               None
# 1495  \n\t\t\t\t\t\t\t\t\t\t\t特定原材料7品目\n\t\t\t\t\t\t...
# 1496  \n\t\t\t\t\t\t\t\t\t\t\t特定原材料7品目\n\t\t\t\t\t\t...
# 1497  \n\t\t\t\t\t\t\t\t\t\t\t特定原材料7品目\n\t\t\t\t\t\t...
#
#                                                    栄養成分  \
# 0     熱量：320kcal、たんぱく質：4.1g、脂質：17.3g、炭水化物：37.9g（糖質：3...
# 1     熱量：306kcal、たんぱく質：4.1g、脂質：16.0g、炭水化物：37.4g（糖質：3...
# 2     熱量：260kcal、たんぱく質：3.5g、脂質：12.8g、炭水化物：33.4g（糖質：3...
# 3     熱量：478kcal、たんぱく質：18.8g、脂質：34.0g、炭水化物：25.1g（糖質：...
# 4     熱量：511kcal、たんぱく質：24.1g、脂質：25.6g、炭水化物：47.9g（糖質：...
# ...                                                 ...
# 1493  熱量：37kcal、たんぱく質：0.6g、脂質：0.4g、炭水化物：9.3g（糖質：7.7g...
# 1494                                               None
# 1495  熱量：260kcal、たんぱく質：3.9g、脂質：0.5g、炭水化物：62.4g、食塩相当量...
# 1496  熱量：26kcal、たんぱく質：0.6g、脂質：0.1g、炭水化物：6.1g（糖質：3.4g...
# 1497  熱量：59kcal、たんぱく質：1.5g、脂質：0.1g、炭水化物：13.4g（糖質：11....
#
#                                                 URL       店名 主要原料・主要原料原産地  \
# 0     https://www.sej.co.jp/products/a/item/051550/  セブンイレブン         None
# 1     https://www.sej.co.jp/products/a/item/051545/  セブンイレブン         None
# 2     https://www.sej.co.jp/products/a/item/050516/  セブンイレブン         None
# 3     https://www.sej.co.jp/products/a/item/051402/  セブンイレブン         None
# 4     https://www.sej.co.jp/products/a/item/051555/  セブンイレブン         None
# ...                                             ...      ...          ...
# 1493  https://www.sej.co.jp/products/a/item/250998/  セブンイレブン         None
# 1494  https://www.sej.co.jp/products/a/item/251026/  セブンイレブン         None
# 1495  https://www.sej.co.jp/products/a/item/250735/  セブンイレブン         None
# 1496  https://www.sej.co.jp/products/a/item/250594/  セブンイレブン         None
# 1497  https://www.sej.co.jp/products/a/item/252590/  セブンイレブン         None
#
#        原産国  税抜き  税込み   カロリー カロリーフラグ
# 0     None  340  367  320.0       3
# 1     None  340  367  306.0       3
# 2     None  390  421  260.0       2
# 3     None  310  334  478.0       4
# 4     None  380  410  511.0       5
# ...    ...  ...  ...    ...     ...
# 1493  None  188  203   37.0       0
# 1494  None  195  210    NaN
# 1495  None  338  365  260.0       2
# 1496  None  278  300   26.0       0
# 1497  None  248  267   59.0       0
#
# [1498 rows x 13 columns]

# %%
def main(cal,item):
    cal_flag = cal / 100
    cal_flag = int(cal_flag)
    count = 1
    
    print('上限は{0}kcal'.format(cal))
    print('アイテム数'+ str(item))
    
    if item == 1:
        df1 = df.query('カロリーフラグ == @cal_flag-1').reset_index() #ここをDBからSQLでひっぱるコードに変える？
        rnd = random.randrange(len(df1))
        cal = df1['カロリー'][rnd]
        name = df1['商品名'][rnd]
        print(name,cal)
        print('合計カロリー:'+ str(cal) )
    
    elif item == 2:
        seg_rnd = random.randrange(1,cal_flag)
        seg1 = seg_rnd
        seg2 = cal_flag - seg_rnd
        
        df1 = df.query('カロリーフラグ == @seg1-1').reset_index()
        df2 = df.query('カロリーフラグ == @seg2-1').reset_index()
        
        rnd1 = random.randrange(len(df1))
        cal1 = df1['カロリー'][rnd1]
        name1 = df1['商品名'][rnd1]
        
        rnd2 = random.randrange(len(df2))
        cal2 = df2['カロリー'][rnd2]
        name2 = df2['商品名'][rnd2]
        
        sum = cal1 + cal2
        
        print(seg1,name1,cal1)
        print(seg2,name2,cal2)
        print('合計カロリー:'+ str(sum) )
        
    else:
        tmp = []
        while count < item-1:
            seg_rnd = random.randrange(1,cal_flag)
            seg1 = seg_rnd
            seg2 = cal_flag - seg_rnd
            if seg1 < seg2:
                seg_main = seg1
                df1 = df.query('カロリーフラグ == @seg_main-1').reset_index()
                
                rnd = random.randrange(len(df1))
                tmp.append(seg_main)
                tmp.append(df1['カロリー'][rnd])
                tmp.append(df1['商品名'][rnd])
                count += 1
                cal_flag -= seg_main
            
            elif seg1 > seg2:
                seg_main = seg2
                df1 = df.query('カロリーフラグ == @seg_main-1').reset_index()
                
                rnd = random.randrange(len(df1))
                tmp.append(seg_main)
                tmp.append(df1['カロリー'][rnd])
                tmp.append(df1['商品名'][rnd])
                count+=1
                cal_flag -= seg_main
                
            else:
                seg_main = seg1
                df1 = df.query('カロリーフラグ == @seg_main-1').reset_index()
                
                rnd = random.randrange(len(df1))
                tmp.append(seg_main)
                tmp.append(df1['カロリー'][rnd])
                tmp.append(df1['商品名'][rnd])
                count+=1
                cal_flag -= seg_main
        
        print('ループはOK')
                
        seg_rnd = random.randrange(1,cal_flag)
        seg1 = seg_rnd
        seg2 = cal_flag - seg_rnd  
        
        df1 = df.query('カロリーフラグ == @seg1-1').reset_index()
        df2 = df.query('カロリーフラグ == @seg2-1').reset_index()
        
        rnd1 = random.randrange(len(df1))
        cal1 = df1['カロリー'][rnd1]
        name1 = df1['商品名'][rnd1]
        
        rnd2 = random.randrange(len(df2))
        cal2 = df2['カロリー'][rnd2]
        name2 = df2['商品名'][rnd2]
        
        tmp.append(seg1)
        tmp.append(cal1)
        tmp.append(name1)
        tmp.append(seg2)
        tmp.append(cal2)
        tmp.append(name2)      
        
        if item == 3:
            print(tmp[0],tmp[1],tmp[2])
            print(tmp[3],tmp[4],tmp[5])
            print(tmp[6],tmp[7],tmp[8])
            sum = tmp[1] + tmp[4] + tmp[7]
            print('合計カロリー:'+ str(sum) )
        if item == 4:
            print(tmp[0],tmp[1],tmp[2])
            print(tmp[3],tmp[4],tmp[5])
            print(tmp[6],tmp[7],tmp[8])
            print(tmp[9],tmp[10],tmp[11])
            sum = tmp[1] + tmp[4] + tmp[7] +tmp[10]
            print('合計カロリー:'+ str(sum) )

# %%
# cal_list = [100,200,300,400,500,600,700,800,900,1000]
'''
問題点
・3品の時は下限が300kcal,4品の時は下限が400kcalじゃないとセグメントできなくてエラー吐く-> フロント側ではじいてもらう。
・カロリーは上限から-100kcalの範囲に収めるのが難しい。 
'''
cal_list = [400,500,600,700,800,900,1000]
cal = cal_list[random.randrange(0,7)]
item = random.randrange(3,5)
main(cal,item)
# Out:
# 上限は800kcal
# アイテム数3
# ループはOK
# 2 175.0 カリカリ梅おむすび
# 1 38.0 塩昆布で食べるおつまみかぶ胡瓜
# 5 423.0 たまごサンド
# 合計カロリー:636.0
